# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_data.SalePrice.mean()
# Out:
# 180921.19589041095

# %%
train_data.MSSubClass.value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
sns.boxplot(x=train_data.MSSubClass, y=np.log(train_data.SalePrice))
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='SalePrice'>

# %%
sns.countplot(train_data.MSSubClass)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MSSubClass', ylabel='count'>

# %%
sns.boxplot(x=train_data.MSZoning, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='SalePrice'>

# %%
sns.countplot(train_data.MSZoning)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MSZoning', ylabel='count'>

# %%
sns.distplot(x=train_data.LotFrontage)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.scatterplot(x=train_data.LotFrontage, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='SalePrice'>

# %%
diff = 1460 - train_data.LotFrontage.count()
diff
# Out:
# 259

# %%
sns.scatterplot(x=train_data.LotArea, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
sns.countplot(train_data.Street)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Street', ylabel='count'>

# %%
(train_data.Street.value_counts()/1460)*100
# Out:
# Pave    99.589041
# Grvl     0.410959
# Name: Street, dtype: float64

# %%
sns.boxplot(x=train_data.Street, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='Street', ylabel='SalePrice'>

# %%
sns.countplot(train_data.Alley)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Alley', ylabel='count'>

# %%
train_data.Alley.value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
train_data.Alley.fillna("NO", inplace=True)
train_data.Alley.value_counts()
# Out:
# NO      1369
# Grvl      50
# Pave      41
# Name: Alley, dtype: int64

# %%
sns.countplot(train_data.Alley)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Alley', ylabel='count'>

# %%
sns.boxplot(x=train_data.Alley,y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='Alley', ylabel='SalePrice'>

# %%
sns.countplot(train_data.LotShape)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LotShape', ylabel='count'>

# %%
train_data.LotShape.value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
sns.barplot(x=train_data.LotShape,y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='LotShape', ylabel='SalePrice'>

# %%
sns.boxplot(x=train_data.LotShape,y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='LotShape', ylabel='SalePrice'>

# %%
sns.countplot(train_data.LandContour)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LandContour', ylabel='count'>

# %%
train_data.LandContour.value_counts()
# Out:
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64

# %%
sns.barplot(x=train_data.LandContour, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='LandContour', ylabel='SalePrice'>

# %%
sns.boxplot(x=train_data.LandContour, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='LandContour', ylabel='SalePrice'>

# %%
sns.countplot(train_data.Utilities)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Utilities', ylabel='count'>

# %%
train_data.Utilities.value_counts()
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
sns.boxplot(x=train_data.Utilities, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='Utilities', ylabel='SalePrice'>

# %%
sns.countplot(train_data.LotConfig)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LotConfig', ylabel='count'>

# %%
train_data.LotConfig.value_counts()
# Out:
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64

# %%
sns.barplot(x=train_data.LotConfig, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='LotConfig', ylabel='SalePrice'>

# %%
sns.boxplot(x=train_data.LotConfig, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='LotConfig', ylabel='SalePrice'>

# %%
sns.countplot(train_data.LandSlope)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LandSlope', ylabel='count'>

# %%
train_data.LandSlope.value_counts()
# Out:
# Gtl    1382
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64

# %%
sns.boxplot(x=train_data.LandSlope, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='LandSlope', ylabel='SalePrice'>

# %%
train_data.Neighborhood.value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
ax = sns.barplot(x=train_data.Neighborhood, y=train_data.SalePrice)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
ax.plot()
# Out:
# []

# %%
sns.countplot(train_data.Condition1)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Condition1', ylabel='count'>

# %%
train_data.Condition1.value_counts()
# Out:
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64

# %%
ax = sns.barplot(x=train_data.Condition1, y=train_data.SalePrice)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
ax.plot()
# Out:
# []

# %%
ax = sns.boxplot(x=train_data.Condition1, y=train_data.SalePrice)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
ax.plot()
# Out:
# []

# %%
sns.countplot(train_data.Condition2)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Condition2', ylabel='count'>

# %%
train_data.Condition2.value_counts()
# Out:
# Norm      1445
# Feedr        6
# PosN         2
# Artery       2
# RRNn         2
# RRAe         1
# PosA         1
# RRAn         1
# Name: Condition2, dtype: int64

# %%
sns.boxplot(x=train_data.Condition2,y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='Condition2', ylabel='SalePrice'>

# %%
sns.countplot(train_data.BldgType)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BldgType', ylabel='count'>

# %%
train_data.BldgType.value_counts()
# Out:
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
sns.boxplot(x=train_data.BldgType, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='SalePrice'>

# %%
sns.countplot(train_data.HouseStyle)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HouseStyle', ylabel='count'>

# %%
train_data.HouseStyle.value_counts()
# Out:
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64

# %%
sns.boxplot(x=train_data.HouseStyle, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='HouseStyle', ylabel='SalePrice'>

# %%
sns.countplot(train_data.OverallQual)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OverallQual', ylabel='count'>

# %%
train_data.OverallQual.value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
sns.boxplot(x=train_data.OverallQual, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.barplot(x=train_data.OverallQual, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.countplot(train_data.OverallCond )
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OverallCond', ylabel='count'>

# %%
sns.boxplot(x=train_data.OverallCond, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='OverallCond', ylabel='SalePrice'>

# %%
ax = sns.scatterplot(x=train_data.YearBuilt, y=train_data.SalePrice)

# %%
ax = sns.scatterplot(x=train_data.YearRemodAdd, y=train_data.SalePrice)

# %%
sns.countplot(train_data.RoofStyle)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='RoofStyle', ylabel='count'>

# %%
train_data.RoofStyle.value_counts()
# Out:
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: RoofStyle, dtype: int64

# %%
sns.boxplot(x=train_data.RoofStyle, y=train_data.SalePrice)
# Out:
# <AxesSubplot:xlabel='RoofStyle', ylabel='SalePrice'>

# %%
sns.countplot(train_data.RoofMatl)
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='RoofMatl', ylabel='count'>

# %%
train_data.RoofMatl.value_counts()
# Out:
# CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Metal         1
# Membran       1
# ClyTile       1
# Roll          1
# Name: RoofMatl, dtype: int64

# %%
axn = sns.barplot(x=train_data.RoofMatl, y=train_data.SalePrice)
axn.set_xticklabels(axn.get_xticklabels(), rotation=90, ha="right")
axn.plot()
# Out:
# []

# %%
axn = sns.boxplot(x=train_data.RoofMatl, y=train_data.SalePrice)
axn.set_xticklabels(axn.get_xticklabels(), rotation=90, ha="right")
axn.plot()
# Out:
# []

# %%
ax = sns.countplot(train_data.Exterior1st)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
ax.plot()
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# []

# %%
train_data.Exterior1st.value_counts()
# Out:
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# BrkComm      2
# Stone        2
# CBlock       1
# AsphShn      1
# ImStucc      1
# Name: Exterior1st, dtype: int64

# %%
ax = sns.barplot(x=train_data.Exterior1st,y=train_data.SalePrice)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90, ha="right")
ax.plot()
# Out:
# []

# %%
ax = sns.boxplot(x=train_data.Exterior1st,y=train_data.SalePrice)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90, ha="right")
ax.plot()
# Out:
# []

# %%
ax = sns.countplot(train_data.Exterior2nd)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90, ha="right")
ax.plot()
# Out:
# D:\Workstation\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# []

# %%
train_data.Exterior2nd.value_counts()
# Out:
# VinylSd    504
# MetalSd    214
# HdBoard    207
# Wd Sdng    197
# Plywood    142
# CmentBd     60
# Wd Shng     38
# Stucco      26
# BrkFace     25
# AsbShng     20
# ImStucc     10
# Brk Cmn      7
# Stone        5
# AsphShn      3
# CBlock       1
# Other        1
# Name: Exterior2nd, dtype: int64

# %%
ax = sns.barplot(x=train_data.Exterior2nd,y=train_data.SalePrice)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90, ha="right")
ax.plot()
# Out:
# []

# %%
ax = sns.boxplot(x=train_data.Exterior2nd,y=train_data.SalePrice)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90, ha="right")
ax.plot()
# Out:
# []

# %%
train_data.MasVnrType.value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
ax = sns.barplot(x=train_data.MasVnrType,y=train_data.SalePrice)

# %%
ax = sns.boxplot(x=train_data.MasVnrType,y=train_data.SalePrice)

# %%
ax = sns.scatterplot(y=train_data.MasVnrArea,x=train_data.SalePrice)

# %%
ax = sns.boxplot(y=train_data.MasVnrArea,x=train_data.MasVnrType)

# %%
train_data.ExterQual.value_counts()
# Out:
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: ExterQual, dtype: int64

# %%
ax = sns.barplot(x=train_data.ExterQual,y=train_data.SalePrice)

# %%
ax = sns.boxplot(x=train_data.ExterQual,y=train_data.SalePrice)

# %%
train_data.ExterCond.value_counts()
# Out:
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64

# %%
ax = sns.barplot(x=train_data.ExterCond,y=train_data.SalePrice)

# %%
ax = sns.boxplot(x=train_data.ExterCond,y=train_data.SalePrice)

# %%
train_data.Foundation.value_counts()
# Out:
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: Foundation, dtype: int64

# %%
ax = sns.barplot(x=train_data.Foundation,y=train_data.SalePrice)

# %%
ax = sns.boxplot(x=train_data.Foundation,y=train_data.SalePrice)

# %%
train_data.BsmtQual.value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64
